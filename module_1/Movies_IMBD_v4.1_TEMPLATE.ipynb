# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
from itertools import combinations

# %%
data = pd.read_csv('movie_bd_v5.csv')
data.sample(5)
# Out:
#        imdb_id     budget    revenue       original_title  \
# 7    tt3659388  108000000  595380321          The Martian
# 399  tt0892791  165000000  752600867  Shrek Forever After
# 546  tt0211443   11000000   16000000              Jason X
# 22   tt2126355  110000000  470490832          San Andreas
# 439  tt1666186   20000000   80547866        Vampires Suck
#
#                                                   cast  \
# 7    Matt Damon|Jessica Chastain|Kristen Wiig|Jeff ...
# 399  Mike Myers|Eddie Murphy|Cameron Diaz|Antonio B...
# 546  Kane Hodder|Lexa Doig|Chuck Campbell|Lisa Ryde...
# 22   Dwayne Johnson|Alexandra Daddario|Carla Gugino...
# 439  Chris Riggi|Matt Lanter|Jenn Proske|Ken Jeong|...
#
#                           director  \
# 7                     Ridley Scott
# 399                  Mike Mitchell
# 546                    James Isaac
# 22                     Brad Peyton
# 439  Jason Friedberg|Aaron Seltzer
#
#                                                tagline  \
# ...

# %%
data.describe()
# Out:
#              budget       revenue      runtime  vote_average  release_year
# count  1.889000e+03  1.889000e+03  1889.000000   1889.000000   1889.000000
# mean   5.431083e+07  1.553653e+08   109.658549      6.140762   2007.860773
# std    4.858721e+07  2.146698e+08    18.017041      0.764763      4.468841
# min    5.000000e+06  2.033165e+06    63.000000      3.300000   2000.000000
# 25%    2.000000e+07  3.456058e+07    97.000000      5.600000   2004.000000
# 50%    3.800000e+07  8.361541e+07   107.000000      6.100000   2008.000000
# 75%    7.200000e+07  1.782626e+08   120.000000      6.600000   2012.000000
# max    3.800000e+08  2.781506e+09   214.000000      8.100000   2015.000000

# %% [markdown]
# # Предобработка

# %%
answers = {} # создадим словарь для ответов

# тут другие ваши предобработки колонок например:

#Счиаем прибыль
data['profit'] = data['revenue'] - data['budget']

#Добавляем столбец с месяцем релиза
data['month'] = pd.to_datetime(data.release_date).dt.month

#Разбиваем строки geners с несколькими жанрами
data_genres_split = data.copy()
data_genres_split.genres = data_genres_split.genres.str.split('|')
data_genres_split = data_genres_split.explode('genres')

#Разбиваем строки geners с несколькими режисёрами
data_director_split = data.copy()
data_director_split.director = data_director_split.director.str.split('|')
data_director_split = data_director_split.explode('director')

#Разбиваем строки cast с несколькими актёрами
data_cast_split = data.copy()
data_cast_split.cast = data_cast_split.cast.str.split('|')
data_cast_split = data_cast_split.explode('cast')

#Разбиваем строки production_companies с несколькими издателями
data_production_split = data.copy()
data_production_split.production_companies = data_production_split.production_companies.str.split('|')
data_production_split = data_production_split.explode('production_companies')


#the time given in the dataset is in string format.
#So we need to change this in datetime format
# ...

# %% [markdown]
# # 1. У какого фильма из списка самый большой бюджет?

# %% [markdown]
# Использовать варианты ответов в коде решения запрещено.
# Вы думаете и в жизни у вас будут варианты ответов?)

# %%
# в словарь вставляем номер вопроса и ваш ответ на него
# Пример: 
answers['1'] = '2. Spider-Man 3 (tt0413300)'
# запишите свой вариант ответа
answers['1'] = '5. Pirates of the Caribbean: On Stranger Tides (tt1298650)' #+
# если ответили верно, можете добавить комментарий со значком "+"

# %%
# тут пишем ваш код для решения данного вопроса:
data[data['budget'] == data.budget.max()]
# Out:
#        imdb_id     budget     revenue  \
# 723  tt1298650  380000000  1021683000
#
#                                   original_title  \
# 723  Pirates of the Caribbean: On Stranger Tides
#
#                                                   cast      director  \
# 723  Johnny Depp|PenÃ©lope Cruz|Geoffrey Rush|Ian M...  Rob Marshall
#
#                          tagline  \
# 723  Live Forever Or Die Trying.
#
#                                               overview  runtime  \
# 723  Captain Jack Sparrow crosses paths with a woma...      136
#
#                        genres  \
# 723  Adventure|Action|Fantasy
#
#                                   production_companies release_date  \
# 723  Walt Disney Pictures|Jerry Bruckheimer Films|M...    5/11/2011
#
#      vote_average  release_year     profit  month
# 723           6.3          2011  641683000      5

# %% [markdown]
# ВАРИАНТ 2

# %%
# можно добавлять разные варианты решения

# %% [markdown]
# # 2. Какой из фильмов самый длительный (в минутах)?

# %%
# думаю логику работы с этим словарем вы уже поняли, 
# по этому не буду больше его дублировать
answers['2'] = '2. Gods and Generals (tt0279111)' #+

# %%
data[data['runtime'] == data.runtime.max()]
# Out:
#         imdb_id    budget   revenue     original_title  \
# 1157  tt0279111  56000000  12923936  Gods and Generals
#
#                                                    cast           director  \
# 1157  Stephen Lang|Jeff Daniels|Robert Duvall|Kevin ...  Ronald F. Maxwell
#
#                                   tagline  \
# 1157  The nations heart was touched by...
#
#                                                overview  runtime  \
# 1157  The film centers mostly around the personal an...      214
#
#                  genres                production_companies release_date  \
# 1157  Drama|History|War  Turner Pictures|Antietam Filmworks    2/21/2003
#
#       vote_average  release_year    profit  month
# 1157           5.8          2003 -43076064      2

# %% [markdown]
# # 3. Какой из фильмов самый короткий (в минутах)?

# %%
answers['3'] = '3. Winnie the Pooh (tt1449283)' #+

# %%
data[data['runtime'] == data.runtime.min()]
# Out:
#        imdb_id    budget   revenue   original_title  \
# 768  tt1449283  30000000  14460000  Winnie the Pooh
#
#                                                   cast  \
# 768  Jim Cummings|Travis Oates|Jim Cummings|Bud Luc...
#
#                       director   tagline  \
# 768  Stephen Anderson|Don Hall  Oh Pooh.
#
#                                               overview  runtime  \
# 768  During an ordinary day in Hundred Acre Wood, W...       63
#
#                genres                               production_companies  \
# 768  Animation|Family  Walt Disney Pictures|Walt Disney Animation Stu...
#
#     release_date  vote_average  release_year    profit  month
# 768    4/13/2011           6.8          2011 -15540000      4

# %% [markdown]
# # 4. Какова средняя длительность фильмов?

# %%
answers['4'] = '2. 110' #+

# %%
data.runtime.mean()
# Out:
# 109.6585494970884

# %% [markdown]
# # 5. Каково медианное значение длительности фильмов?

# %%
answers['5'] = '1. 107' #+

# %%
data.runtime.median()
# Out:
# 107.0

# %% [markdown]
# # 6. Какой самый прибыльный фильм?
# #### Внимание! Здесь и далее под «прибылью» или «убытками» понимается разность между сборами и бюджетом фильма. (прибыль = сборы - бюджет) в нашем датасете это будет (profit = revenue - budget)

# %%
# лучше код получения столбца profit вынести в Предобработку что в начале

answers['6'] = '5. Avatar (tt0499549)' #+

data[data['profit'] == data.profit.max()]
# Out:
#        imdb_id     budget     revenue original_title  \
# 239  tt0499549  237000000  2781505847         Avatar
#
#                                                   cast       director  \
# 239  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...  James Cameron
#
#                          tagline  \
# 239  Enter the World of Pandora.
#
#                                               overview  runtime  \
# 239  In the 22nd century, a paraplegic Marine is di...      162
#
#                                        genres  \
# 239  Action|Adventure|Fantasy|Science Fiction
#
#                                   production_companies release_date  \
# 239  Ingenious Film Partners|Twentieth Century Fox ...   12/10/2009
#
#      vote_average  release_year      profit  month
# 239           7.1          2009  2544505847     12

# %% [markdown]
# # 7. Какой фильм самый убыточный?

# %%
answers['7'] = '5. The Lone Ranger (tt1210819)' #+

data[data['profit'] == data.profit.min()]
# Out:
#         imdb_id     budget   revenue   original_title  \
# 1245  tt1210819  255000000  89289910  The Lone Ranger
#
#                                                    cast        director  \
# 1245  Johnny Depp|Armie Hammer|William Fichtner|Hele...  Gore Verbinski
#
#                       tagline  \
# 1245  Never Take Off the Mask
#
#                                                overview  runtime  \
# 1245  The Texas Rangers chase down a gang of outlaws...      149
#
#                         genres  \
# 1245  Action|Adventure|Western
#
#                                    production_companies release_date  \
# 1245  Walt Disney Pictures|Jerry Bruckheimer Films|I...     7/3/2013
#
#       vote_average  release_year     profit  month
# 1245           6.0          2013 -165710090      7

# %% [markdown]
# # 8. У скольких фильмов из датасета объем сборов оказался выше бюджета?

# %%
answers['8'] = '1. 1478' #+

len(data[data['revenue'] > data['budget']].value_counts())
# Out:
# 1478

# %% [markdown]
# # 9. Какой фильм оказался самым кассовым в 2008 году?

# %%
answers['9'] = '4. The Dark Knight (tt0468569)' #+

data[data['release_year'] == 2008].sort_values(by='revenue', ascending=False)
# Out:
#        imdb_id     budget     revenue  \
# 599  tt0468569  185000000  1001921825
# 603  tt0367882  185000000   786636033
# 606  tt0441773  130000000   631744560
# 621  tt0448157  150000000   624029371
# 607  tt0795421   52000000   609841637
# ..         ...        ...         ...
# 708  tt0486674   25000000     6673422
# 673  tt0800241   15000000     5926410
# 702  tt0844286   20000000     5530764
# 711  tt0805570   15000000     3533227
# 712  tt0490181    8000000     2033165
#
#                                         original_title  \
# 599                                    The Dark Knight
# 603  Indiana Jones and the Kingdom of the Crystal S...
# 606                                      Kung Fu Panda
# 621                                            Hancock
# 607                                         Mamma Mia!
# ..                                                 ...
# 708                                 What Just Happened
# ...

# %% [markdown]
# # 10. Самый убыточный фильм за период с 2012 по 2014 г. (включительно)?

# %%
answers['10'] = '5. The Lone Ranger (tt1210819)' #+

data[(data['release_year'] >= 2012) & (data['release_year'] <= 2014)].sort_values(by='profit')
# Out:
#         imdb_id     budget     revenue                   original_title  \
# 1245  tt1210819  255000000    89289910                  The Lone Ranger
# 1214  tt0790736  130000000    61648500                         R.I.P.D.
# 1007  tt1374992   60000000     8106475                      Upside Down
# 1302  tt0884726   70000000    18662027  Legends of Oz: Dorothy's Return
# 1235  tt1308729   55000000     9489829               Bullet to the Head
# ...         ...        ...         ...                              ...
# 1189  tt1690953   76000000   970761885                  Despicable Me 2
# 974   tt1074638  200000000  1108561013                          Skyfall
# 1180  tt1300854  200000000  1215439994                       Iron Man 3
# 1177  tt2294629  150000000  1274219009                           Frozen
# 970   tt0848228  220000000  1519557910                     The Avengers
#
#                                                    cast  \
# ...

# %% [markdown]
# # 11. Какого жанра фильмов больше всего?

# %%
# эту задачу тоже можно решать разными подходами, попробуй реализовать разные варианты
# если будешь добавлять функцию - выноси ее в предобработку что в начале
answers['11'] = '3. Drama ' #+

geners_list = data.genres.apply(lambda x:str(x).split('|')).sum() # разбиваем значения с несколькими жанрами
geners_dict = {i:geners_list.count(i) for i in geners_list} # считаем колличесво повторений каждого жанра
geners_dict_sorterd = sorted(geners_dict.items(), key = lambda x:x[1],reverse = True) # сортируем полученный словарь

print(geners_dict_sorterd)
# Out:
# [('Drama', 782), ('Comedy', 683), ('Thriller', 596), ('Action', 582), ('Adventure', 415), ('Crime', 315), ('Romance', 308), ('Family', 260), ('Science Fiction', 248), ('Fantasy', 222), ('Horror', 176), ('Mystery', 168), ('Animation', 139), ('Music', 64), ('History', 62), ('War', 58), ('Western', 19), ('Documentary', 8), ('Foreign', 2)]

# %% [markdown]
# ВАРИАНТ 2

# %%
#Короткий путь
Counter(data.genres.apply(lambda x:str(x).split('|')).sum()).most_common()
# Out:
# [('Drama', 782),
#  ('Comedy', 683),
#  ('Thriller', 596),
#  ('Action', 582),
#  ('Adventure', 415),
#  ('Crime', 315),
#  ('Romance', 308),
#  ('Family', 260),
#  ('Science Fiction', 248),
#  ('Fantasy', 222),
#  ('Horror', 176),
#  ('Mystery', 168),
#  ('Animation', 139),
#  ('Music', 64),
#  ('History', 62),
#  ('War', 58),
#  ('Western', 19),
#  ('Documentary', 8),
#  ('Foreign', 2)]

# %%
#Вариант 3 через explode 

# формирование data_genres_split вынесено в предобработку
data_genres_split.groupby(['genres'])['original_title'].count().sort_values(ascending=False)
# Out:
# genres
# Drama              782
# Comedy             683
# Thriller           596
# Action             582
# Adventure          415
# Crime              315
# Romance            308
# Family             260
# Science Fiction    248
# Fantasy            222
# Horror             176
# Mystery            168
# Animation          139
# Music               64
# History             62
# War                 58
# Western             19
# Documentary          8
# Foreign              2
# Name: original_title, dtype: int64

# %% [markdown]
# # 12. Фильмы какого жанра чаще всего становятся прибыльными?

# %%
answers['12'] = '1. Drama ' #+

data_genres_split[data_genres_split['profit'] > 0].groupby(['genres'])['original_title'].count().sort_values(ascending=False)

#Counter(data[data['profit'] > 0].genres.apply(lambda x:str(x).split('|')).sum()).most_common()
# Out:
# genres
# Drama              560
# Comedy             551
# Thriller           446
# Action             444
# Adventure          337
# Romance            242
# Crime              231
# Family             226
# Science Fiction    195
# Fantasy            188
# Horror             150
# Animation          120
# Mystery            119
# Music               47
# History             46
# War                 41
# Western             12
# Documentary          7
# Name: original_title, dtype: int64

# %% [markdown]
# # 13. У какого режиссера самые большие суммарные кассовые сборы?

# %%
answers['13'] = '5. Peter Jackson' #+

# формирование data_director_split вынесено в предобработку
data_director_split.groupby(['director'])['revenue'].sum().sort_values(ascending=False)
# Out:
# director
# Peter Jackson        6490593685
# Christopher Nolan    4167548502
# David Yates          4154295625
# Michael Bay          3886938960
# J.J. Abrams          3579169916
#                         ...
# David MichÃ´d           2295423
# Steven Shainberg        2281089
# Paul Schrader           2062066
# Keanu Reeves            2054941
# Simon Hunter            2033165
# Name: revenue, Length: 997, dtype: int64

# %% [markdown]
# # 14. Какой режисер снял больше всего фильмов в стиле Action?

# %%
answers['14'] = '3. Robert Rodriguez' #+

data_director_split[data_director_split.genres.str.contains("Action")].groupby(['director'])['imdb_id'].count().sort_values(ascending=False)
# Out:
# director
# Robert Rodriguez      9
# Michael Bay           7
# Paul W.S. Anderson    7
# Ridley Scott          6
# Antoine Fuqua         6
#                      ..
# John Whitesell        1
# Brian A Miller        1
# Jon Amiel             1
# Jon Avnet             1
# Luis Mandoki          1
# Name: imdb_id, Length: 364, dtype: int64

# %% [markdown]
# # 15. Фильмы с каким актером принесли самые высокие кассовые сборы в 2012 году?

# %%
answers['15'] = '3. Chris Hemsworth ' #+

data_cast_split[data_cast_split['release_year'] == 2012].groupby(['cast'])['revenue'].sum().sort_values(ascending=False)
# Out:
# cast
# Chris Hemsworth      2027450773
# Denis Leary          1629460639
# Anne Hathaway        1522851057
# Robert Downey Jr.    1519557910
# Mark Ruffalo         1519557910
#                         ...
# Michael Nyqvist         3428048
# Danny Huston            2106557
# Josh Lucas              2106557
# Sami Gayle              2106557
# Nicolas Cage            2106557
# Name: revenue, Length: 466, dtype: int64

# %% [markdown]
# # 16. Какой актер снялся в большем количестве высокобюджетных фильмов?

# %%
answers['16'] = '3. Matt Damon' #+

data_cast_split[data_cast_split.budget > data.budget.mean()].groupby(['cast'])['imdb_id'].count().sort_values(ascending=False)
# Out:
# cast
# Matt Damon                 18
# Adam Sandler               17
# Angelina Jolie             16
# Tom Cruise                 15
# Eddie Murphy               15
#                            ..
# Jennifer Hudson             1
# Jennifer Jason Leigh        1
# Jennifer Saunders           1
# Jennifer Tilly              1
# Ã“lafur Darri Ã“lafsson     1
# Name: imdb_id, Length: 1505, dtype: int64

# %% [markdown]
# # 17. В фильмах какого жанра больше всего снимался Nicolas Cage?

# %%
answers['17'] = '2. Action ' #+

data_genres_split[data_genres_split.cast.str.contains("Nicolas Cage")].groupby(['genres'])['imdb_id'].count().sort_values(ascending=False)
# Out:
# genres
# Action             17
# Thriller           15
# Drama              12
# Crime              10
# Fantasy             8
# Adventure           7
# Comedy              6
# Science Fiction     4
# Animation           3
# Family              3
# Mystery             3
# History             2
# Horror              1
# Romance             1
# War                 1
# Name: imdb_id, dtype: int64

# %% [markdown]
# # 18. Самый убыточный фильм от Paramount Pictures

# %%
answers['18'] = '1. K-19: The Widowmaker (tt0267626)' #+

data_production_split[data_production_split.production_companies == 'Paramount Pictures'].sort_values('profit',ascending=True)
# Out:
#         imdb_id     budget     revenue  \
# 925   tt0267626  100000000    35168966
# 1123  tt0300556   80000000    19480739
# 1722  tt0435705   70000000    18211013
# 1623  tt0375173   60000000    13395939
# 1631  tt0315297   50000000    25195000
# ...         ...        ...         ...
# 730   tt1229238  145000000   694713380
# 1738  tt0418279  150000000   709709780
# 603   tt0367882  185000000   786636033
# 317   tt1055369  150000000   836297228
# 828   tt1399103  195000000  1123746996
#
#                                          original_title  \
# 925                                K-19: The Widowmaker
# 1123                                           Timeline
# 1722                                               Next
# 1623                                              Alfie
# 1631                                            Twisted
# ...                                                 ...
# 730                Mission: Impossible - Ghost Protocol
# ...

# %% [markdown]
# # 19. Какой год стал самым успешным по суммарным кассовым сборам?

# %%
answers['19'] = '5. 2015' #+

data.groupby('release_year')['revenue'].sum().sort_values(ascending=False)
# Out:
# release_year
# 2015    25449202382
# 2014    23405862953
# 2013    23213799791
# 2012    23079001687
# 2011    22676791872
# 2010    21071204961
# 2009    20261791024
# 2008    18252781990
# 2007    18162406801
# 2004    15663430720
# 2005    15309425558
# 2006    14775042320
# 2003    14346123312
# 2002    14136361487
# 2001    13017764865
# 2000    10664099805
# Name: revenue, dtype: int64

# %% [markdown]
# # 20. Какой самый прибыльный год для студии Warner Bros?

# %%
answers['20'] = '1. 2014' #+

data[data.production_companies.str.contains('Warner Bros')].groupby('release_year')['profit'].sum().sort_values(ascending=False)
# Out:
# release_year
# 2014    2295464519
# 2007    2201675217
# 2008    2134595031
# 2010    1974712985
# 2011    1871393682
# 2003    1855493377
# 2009    1822454136
# 2013    1636453400
# 2004    1631933725
# 2005    1551980298
# 2001    1343545668
# 2012    1258020056
# 2002    1022709901
# 2015     870368348
# 2006     620170743
# 2000     452631386
# Name: profit, dtype: int64

# %% [markdown]
# # 21. В каком месяце за все годы суммарно вышло больше всего фильмов?

# %%
answers['21'] = '4. Сентябрь' #+

data['month'].value_counts()
# Out:
# 9     227
# 12    190
# 10    186
# 8     161
# 3     156
# 4     149
# 6     147
# 11    146
# 7     142
# 5     140
# 2     135
# 1     110
# Name: month, dtype: int64

# %% [markdown]
# # 22. Сколько суммарно вышло фильмов летом? (за июнь, июль, август)

# %%
answers['22'] = '2. 450' #+

data[(data.month >= 6) & (data.month <= 8)].count()
# Out:
# imdb_id                 450
# budget                  450
# revenue                 450
# original_title          450
# cast                    450
# director                450
# tagline                 450
# overview                450
# runtime                 450
# genres                  450
# production_companies    450
# release_date            450
# vote_average            450
# release_year            450
# profit                  450
# month                   450
# dtype: int64

# %% [markdown]
# # 23. Для какого режиссера зима – самое продуктивное время года?

# %%
#Вопрос 23. Какой режиссер выпускает (суммарно по годам) больше всего фильмов зимой?
answers['23'] = '5. Peter Jackson' #+

data_director_split[(data_director_split.month == 12) | (data_director_split.month <= 2)].groupby(['director'])['imdb_id'].count().sort_values(ascending=False)
# Out:
# director
# Peter Jackson        7
# Steven Soderbergh    6
# Clint Eastwood       6
# Shawn Levy           4
# Adam Shankman        4
#                     ..
# John Luessenhop      1
# John Musker          1
# John Polson          1
# Callan Brunker       1
# Xavier Palud         1
# Name: imdb_id, Length: 358, dtype: int64

# %% [markdown]
# # 24. Какая студия дает самые длинные названия своим фильмам по количеству символов?

# %%
answers['24'] = '5. Four By Two Productions' #+

data_24 = data_production_split.copy()
data_24['tite_len'] = data_24.original_title.apply(lambda x: len(str(x)))
data_24.sort_values('tite_len', ascending=False)
# Out:
#         imdb_id     budget    revenue  \
# 1448  tt0443453   18000000  261572744
# 1448  tt0443453   18000000  261572744
# 1314  tt0363771  180000000  748806957
# 1314  tt0363771  180000000  748806957
# 219   tt1698641   28000000  100654149
# ...         ...        ...        ...
# 252   tt0472033   30000000   48428063
# 252   tt0472033   30000000   48428063
# 252   tt0472033   30000000   48428063
# 252   tt0472033   30000000   48428063
# 252   tt0472033   30000000   48428063
#
#                                          original_title  \
# 1448  Borat: Cultural Learnings of America for Make ...
# 1448  Borat: Cultural Learnings of America for Make ...
# 1314  The Chronicles of Narnia: The Lion, the Witch ...
# 1314  The Chronicles of Narnia: The Lion, the Witch ...
# 219   Alexander and the Terrible, Horrible, No Good,...
# ...                                                 ...
# 252                                                   9
# ...

# %% [markdown]
# # 25. Описание фильмов какой студии в среднем самые длинные по количеству слов?

# %%
answers['25'] = '3. Midnight Picture Show' #+

data_25 = data_production_split.copy()
data_25['overview_len'] = data_25.overview.apply(lambda x: len(str(x)))
#data_25.sort_values('overview_len', ascending=False)

data_25.groupby('production_companies')['overview_len'].mean().sort_values(ascending=False)
# Out:
# production_companies
# Midnight Picture Show                    1000.0
# Room 9 Entertainment                      964.0
# Brookwell-McNamara Entertainment          936.0
# Lions Gate Family Entertainment           909.0
# Crest Animation Productions               909.0
#                                           ...
# London Boulevard                           74.0
# Henceforth                                 74.0
# Phantom Four                               72.0
# Empire Pictures                            62.0
# Motion Picture Corporation of America      59.0
# Name: overview_len, Length: 1771, dtype: float64

# %% [markdown]
# # 26. Какие фильмы входят в 1 процент лучших по рейтингу?
# по vote_average

# %%
answers['26'] = '1. Inside Out, The Dark Knight, 12 Years a Slave' #+

data[data.vote_average > data.quantile(0.99, numeric_only=True)['vote_average']].groupby('original_title')['vote_average'].mean()
# Out:
# original_title
# 12 Years a Slave                                 7.9
# Gone Girl                                        7.9
# Guardians of the Galaxy                          7.9
# Inception                                        7.9
# Inside Out                                       8.0
# Interstellar                                     8.0
# Memento                                          7.9
# Room                                             8.0
# The Dark Knight                                  8.1
# The Grand Budapest Hotel                         7.9
# The Imitation Game                               8.0
# The Lord of the Rings: The Return of the King    7.9
# The Pianist                                      7.9
# The Wolf of Wall Street                          7.9
# Name: vote_average, dtype: float64

# %% [markdown]
# # 27. Какие актеры чаще всего снимаются в одном фильме вместе?

# %% [markdown]
# ВАРИАНТ 2

# %%
answers['27'] = '5. Daniel Radcliffe & Rupert Grint' #+

data_27 = data.copy()
data_27.cast = data_27.cast.str.split('|')
data_27['pairs'] = data_27.cast.apply(lambda s: list(combinations(s, 2)))
data_27 = data_27.explode('pairs')
Counter(data_27.pairs).most_common(1)
# Out:
# [(('Daniel Radcliffe', 'Rupert Grint'), 8)]

# %% [markdown]
# # Submission

# %%
# в конце можно посмотреть свои ответы к каждому вопросу
answers
# Out:
# {'1': '5. Pirates of the Caribbean: On Stranger Tides (tt1298650)',
#  '2': '2. Gods and Generals (tt0279111)',
#  '3': '3. Winnie the Pooh (tt1449283)',
#  '4': '2. 110',
#  '5': '1. 107',
#  '6': '5. Avatar (tt0499549)',
#  '7': '5. The Lone Ranger (tt1210819)',
#  '8': '1. 1478',
#  '9': '4. The Dark Knight (tt0468569)',
#  '10': '5. The Lone Ranger (tt1210819)',
#  '11': '3. Drama ',
#  '12': '1. Drama ',
#  '13': '5. Peter Jackson',
#  '14': '3. Robert Rodriguez',
#  '15': '3. Chris Hemsworth ',
#  '16': '3. Matt Damon',
#  '17': '2. Action ',
#  '18': '1. K-19: The Widowmaker (tt0267626)',
#  '19': '5. 2015',
#  '20': '1. 2014',
#  '21': '4. Сентябрь',
#  '22': '2. 450',
#  '23': '5. Peter Jackson',
#  '24': '5. Four By Two Productions',
#  '25': '3. Midnight Picture Show',
#  '26': '1. Inside Out, The Dark Knight, 12 Years a Slave ',
#  '27': '5. Daniel Radcliffe & Rupert Grint'}

# %%
# и убедиться что ни чего не пропустил)
len(answers)
# Out:
# 27
